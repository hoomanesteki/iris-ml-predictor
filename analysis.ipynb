# %% [markdown]
# # Iris dataset
#  Model Selection and EDA

# %% [markdown]
# ## Summary

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Methods and Results

# %% [markdown]
# ## Discussion

# %% [markdown]
# ## References
